# %%
#1.Loading Data Set

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data = pd.read_csv(r"C:\Users\jaind\OneDrive\Desktop\ML_Project\data\survey.csv")

data
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
#Printing first 5 Rows In Data Set
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
#printing Last 5 Rows In DataSet
data.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# ...

# %%
#To Know no of Rows,Columns In Dataset Using Shape
data.shape
# Out:
# (1259, 27)

# %%
#To Get Data Info Using data.info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
#2.Data Preprocessing

# %%
#Handling Null values
data.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
#we Have 4 Columns Which Have Null Values
#Change The Value not available to anything Efficient To Reduce overfitting And Increase Accuracy
data['self_employed'].value_counts()
# Out:
# self_employed
# No     1095
# Yes     146
# Name: count, dtype: int64

# %%
#As majority self employed Come with No Replace Null values To No
data['self_employed'] = data['self_employed'].fillna('no')

# %%
data['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    465
# Never        213
# Rarely       173
# Often        144
# Name: count, dtype: int64

# %%
data['work_interfere'] = data['work_interfere'].fillna('Sometimes')

# %%
#Now Check whether missing values there are not after handling missing Values
data.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                   0
# family_history                  0
# treatment                       0
# work_interfere                  0
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
#we Sucessfully Handled missing Values
#Try to remove Unwanted columns
#first see what are columns which we dont need for prediction
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
data['Country'].value_counts().plot(kind='bar', figsize=(10,8))
# Out:
# <Axes: xlabel='Country'>

# %%
#Dropping Unwanted Columns
data.drop(['Country', 'Timestamp', 'state', 'comments'], axis=1, inplace=True, errors='ignore')

# %%
# Drop 'leave' column from the dataset
if 'leave' in data.columns:
    data.drop('leave', axis=1, inplace=True)

# %%
#checking all are not null
data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
data['Age'].unique()
# Keep only ages between 10 and 100
data = data[(data['Age'] >= 10) & (data['Age'] <= 100)]

# %%
#Performing Univariate Analysis
#Now Its Perfectly Alright Doing Univariate Analysis To Detect Outliers In Graph
sb.displot(data['Age'], kde=True, color='skyblue')
plt.title('Univariate Analysis of Age')
plt.xlabel('Age')
plt.show()

# %%
# Step 1: Select only object-type columns (categorical/text)
cat_cols = data.select_dtypes(include='object').columns

# Step 2: Apply str.title() to each of those columns
for col in cat_cols:
    data[col] = data[col].astype(str).str.strip().str.title()
# Out:
# C:\Users\jaind\AppData\Local\Temp\ipykernel_28932\3928493140.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].astype(str).str.strip().str.title()
# C:\Users\jaind\AppData\Local\Temp\ipykernel_28932\3928493140.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].astype(str).str.strip().str.title()
# C:\Users\jaind\AppData\Local\Temp\ipykernel_28932\3928493140.py:6: SettingWithCopyWarning:
# ...

# %%
# Now We Need Perform Bivariate Analysis
#Employment Type and Treatment
plt.figure(figsize=(10,5))
sb.countplot(x='self_employed', hue='treatment', data=data, palette='Set2')
plt.title('Bivariate Analysis: Employment Type vs Treatment')
# Out:
# Text(0.5, 1.0, 'Bivariate Analysis: Employment Type vs Treatment')

# %%
# Bivariate: Family History vs Treatment
plt.figure(figsize=(10, 4))
sb.countplot(x='family_history', hue='treatment', data=data)
plt.title('Bivariate Analysis: Family History vs Treatment')
# Out:
# Text(0.5, 1.0, 'Bivariate Analysis: Family History vs Treatment')

# %%
#work interfere and tratment
plt.figure(figsize=(10, 4))
sb.countplot(x='work_interfere', hue='treatment', data=data)
plt.title('Bivariate Analysis: work_interfere vs Treatment')
# Out:
# Text(0.5, 1.0, 'Bivariate Analysis: work_interfere vs Treatment')

# %%
#Work Type And Treatment
#work interfere and tratment
plt.figure(figsize=(10,40))
plt.subplot(9,2,4)
sb.countplot(x='remote_work', hue = 'treatment',data=data)
plt.title('Work Type')
# Out:
# Text(0.5, 1.0, 'Work Type')

# %%
#company and Tretment
plt.figure(figsize=(10,40))
plt.subplot(9,2,5)
sb.countplot(x='tech_company', hue ='treatment',data=data)
plt.title('Company')
# Out:
# Text(0.5, 1.0, 'Company')

# %%
#Benefits and Treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,5)
sb.countplot(x='tech_company', hue = 'treatment',data=data)
plt.title('Company')
# Out:
# Text(0.5, 1.0, 'Company')

# %%
#Care Options And Treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,7)
sb.countplot(x='care_options', hue = 'treatment',data=data)
plt.title('Care Options')
# Out:
# Text(0.5, 1.0, 'Care Options')

# %%
#Mental vs Physical health
plt.figure(figsize=(10,40))
plt.subplot(9,2,8)
sb.countplot(x='mental_vs_physical', hue='treatment', data=data)
plt.title('Equal importance to Mental and Physical health')
# Out:
# Text(0.5, 1.0, 'Equal importance to Mental and Physical health')

# %%
plt.figure(figsize=(10,40))
plt.subplot(9,2,9)
sb.countplot(x='wellness_program', hue='treatment', data=data)
plt.title('Wellness Program')
# Out:
# Text(0.5, 1.0, 'Wellness Program')

# %%
#Anonymity and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,10)
sb.countplot(x='anonymity', hue='treatment', data=data)
plt.title('Anonymity')
# Out:
# Text(0.5, 1.0, 'Anonymity')

# %%
#Mental health consequence and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,12)
sb.countplot(x='mental_health_consequence', hue='treatment', data=data)
plt.title('Mental Health Consequence')
# Out:
# Text(0.5, 1.0, 'Mental Health Consequence')

# %%
#Physical health consequence and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,13)
sb.countplot(x='phys_health_consequence', hue='treatment', data=data)
plt.title('Physical Health Consequence')
# Out:
# Text(0.5, 1.0, 'Physical Health Consequence')

# %%
#Discussion with coworkers and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,14)
sb.countplot(x='coworkers', hue='treatment', data=data)
plt.title('Discussion with Coworkers')
# Out:
# Text(0.5, 1.0, 'Discussion with Coworkers')

# %%
#Mental health discussion during interview and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,16)
sb.countplot(x='mental_health_interview', hue='treatment', data=data)
plt.title('Discussion with Interviewer(Mental)')
# Out:
# Text(0.5, 1.0, 'Discussion with Interviewer(Mental)')

# %%
#Physical health discussion during interview and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,17)
sb.countplot(x='phys_health_interview', hue='treatment', data=data)
plt.title('Discussion with Interviewer(Physical)')
# Out:
# Text(0.5, 1.0, 'Discussion with Interviewer(Physical)')

# %%
#The consequence after disclosure and treatment
plt.figure(figsize=(10,40))
plt.subplot(9,2,18)
sb.countplot(x='obs_consequence', hue='treatment', data=data)
plt.title('Consequence after Disclosure')
# Out:
# Text(0.5, 1.0, 'Consequence after Disclosure')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set plot size and style
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

# Example 1: Age vs Treatment with Gender hue
sns.boxplot(x='treatment', y='Age', hue='Gender', data=data, palette='Set2')
plt.title('Multivariate Analysis: Age vs Treatment by Gender')
plt.show()

# Example 2: Self Employed vs Treatment by Gender
plt.figure(figsize=(10, 6))
sns.countplot(x='self_employed', hue='treatment', data=data, palette='Set1')
plt.title('Multivariate Analysis: Self Employment vs Treatment')
plt.show()

# Example 3: Heatmap of correlation (only for numeric data like Age)
import numpy as np

# Select only numeric data for correlation
numeric_df = data.select_dtypes(include=np.number)

plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numerical Features)')
plt.show()

# %%
#We observe that majority of people have not faced any negative consequences after discussing their mental health conditions in their workplace

# %%
#Now We Need To Do Descriptive Analyisis That means Numerical seeing mean,median those all
data.describe(include='all')
# Out:
#                 Age Gender self_employed family_history treatment  \
# count   1252.000000   1252          1252           1252      1252
# unique          NaN     38             2              2         2
# top             NaN   Male            No             No       Yes
# freq            NaN    820          1109            763       632
# mean      32.059904    NaN           NaN            NaN       NaN
# std        7.309669    NaN           NaN            NaN       NaN
# min       11.000000    NaN           NaN            NaN       NaN
# 25%       27.000000    NaN           NaN            NaN       NaN
# 50%       31.000000    NaN           NaN            NaN       NaN
# 75%       36.000000    NaN           NaN            NaN       NaN
# max       72.000000    NaN           NaN            NaN       NaN
#
#        work_interfere no_employees remote_work tech_company benefits  ...  \
# count            1252         1252        1252         1252     1252  ...
# ...

# %%
#we need to convert Categorial data to Labels

# %%
#importing Requirements
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
import joblib

from sklearn.model_selection import train_test_split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer

# ✅ Load your dataset
# data = pd.read_csv('your_file.csv')  # Uncomment and replace with your actual file path

# ✅ Step 1: Convert 'Age' to numeric and filter valid values
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')
data = data.loc[(data['Age'] > 0) & (data['Age'] < 100)].copy()
data.dropna(subset=['Age'], inplace=True)

# ✅ Step 2: Drop unnecessary or unhelpful columns (if present)
columns_to_drop = ['Country', 'Timestamp', 'state', 'comments', 'leave']
data.drop(columns=[col for col in columns_to_drop if col in data.columns], inplace=True)

# ✅ Step 3: Split features (X) and target (y)
if 'treatment' not in data.columns:
    raise KeyError("'treatment' column not found!")

X = data.drop('treatment', axis=1)
y = data['treatment']

# ✅ Step 4: Encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# ✅ Step 5: Identify numeric and categorical features
num_cols = ['Age']
cat_cols = [col for col in X.columns if col not in num_cols]

# ✅ Step 6: Define column transformer (scaling + encoding)
ct = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), cat_cols)
    ]
)

# ✅ Step 7: Apply transformations to the features
X_transformed = ct.fit_transform(X)

# ✅ Step 8: Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_transformed, y, test_size=0.3, random_state=49
)

# %%
#checking
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((876, 21), (376, 21), (876,), (376,))

# %%
#import model we need to train our Model  
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import accuracy_score, roc_curve, confusion_matrix, classification_report, auc

# %%
#Build the models
model_dict = {}

model_dict['Logistic regression']= LogisticRegression(solver='liblinear',random_state=49)
model_dict['KNN Classifier'] = KNeighborsClassifier()
model_dict['Decision Tree Classifier'] = DecisionTreeClassifier(random_state=49)
model_dict['Random Forest Classifier'] = RandomForestClassifier(random_state=49)
model_dict['AdaBoost Classifier'] = AdaBoostClassifier(random_state=49,algorithm='SAMME')
model_dict['Gradient Boosting Classifier'] = GradientBoostingClassifier(random_state=49)

# %%
#printing Accuracy of each model
def model_test(X_train, X_test, y_train, y_test,model,model_name):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    print('===================================================={}===================================================='.format(model_name))
    print('Score is : {}'.format(accuracy))

    print()

# %%
for model_name,model in model_dict.items():
    model_test(X_train, X_test, y_train, y_test, model, model_name)
# Out:
# ====================================================Logistic regression====================================================
# Score is : 0.7367021276595744
#
# ====================================================KNN Classifier====================================================
# Score is : 0.6702127659574468
#
# ====================================================Decision Tree Classifier====================================================
# Score is : 0.6781914893617021
#
# ====================================================Random Forest Classifier====================================================
# Score is : 0.75
#
# ====================================================AdaBoost Classifier====================================================
# Score is : 0.7473404255319149
#
# ====================================================Gradient Boosting Classifier====================================================
# Score is : 0.7420212765957447

# %%
#best accuracy is Adaboost
abc = AdaBoostClassifier(random_state=99)
base = DecisionTreeClassifier(max_depth=3)
abc.fit(X_train,y_train)
pred_abc = abc.predict(X_test)
print('Accuracy of AdaBoost=',accuracy_score(y_test,pred_abc))
# Out:
# Accuracy of AdaBoost= 0.7367021276595744
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
#To increase Accuracy We Do either Hyperparameter tuning or grid search im prefering Grid Search

# %%
#we Need To Improve our model so use hyperparameter tuning but i dint get much results in it so i used Grid search
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Base model
abc = AdaBoostClassifier(random_state=49)

# %%
param_grid = {
    'n_estimators': [10, 25, 50, 75, 100],
    'learning_rate': [0.5, 1.0, 1.5],
    
}

# GridSearchCV setup
grid = GridSearchCV(estimator=abc, param_grid=param_grid, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=49), n_jobs=-1,
#              param_grid={'learning_rate': [0.5, 1.0, 1.5],
#                          'n_estimators': [10, 25, 50, 75, 100]})

# %%
# Best model
print("Best Parameters:", grid.best_params_)

# Evaluate
y_pred_grid = grid.predict(X_test)
print("Grid Search Accuracy:", accuracy_score(y_test, y_pred_grid))
# Out:
# Best Parameters: {'learning_rate': 0.5, 'n_estimators': 75}
# Grid Search Accuracy: 0.7553191489361702

# %%
import pickle, joblib
best_model = grid.best_estimator_

pickle.dump(best_model, open("model.pkl", "wb"))
joblib.dump(ct, "feature_values.pkl")
joblib.dump(le, "label_encoder.pkl")
# Out:
# ['label_encoder.pkl']

# %%
#Confusion Matrix after training
cf_matrix = confusion_matrix(y_test, pred_abc)
sb.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, fmt='.2%')
plt.title('Confusion Matrix of AdaBoost Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
#this is  After Grid Search
cf_matrix = confusion_matrix(y_test, y_pred_grid)
sb.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, fmt='.2%')
plt.title('Confusion Matrix of AdaBoost Classifier after Grid Search')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
#Roc Curve
fpr_abc, tpr_abc, thresholds_abc = roc_curve(y_test, pred_abc)
roc_auc_abc = auc(fpr_abc, tpr_abc)

plt.plot(fpr_abc, tpr_abc, color='orange', label='ROC curve (area = %0.2f)' % roc_auc_abc)
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.legend(loc="lower right")
plt.show()

# %%
#Roc curve
fpr_abc, tpr_abc, thresholds_abc = roc_curve(y_test, y_pred_grid)
roc_auc_abc = auc(fpr_abc, tpr_abc)

plt.plot(fpr_abc, tpr_abc, color='orange', label='ROC curve (area = %0.2f)' % roc_auc_abc)
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.legend(loc="lower right")
plt.show()

# %%
#Classification Report
print(classification_report(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.74       184
#            1       0.75      0.72      0.74       192
#
#     accuracy                           0.74       376
#    macro avg       0.74      0.74      0.74       376
# weighted avg       0.74      0.74      0.74       376

# %%
#Classification Report After Grid Search
print(classification_report(y_test,y_pred_grid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       184
#            1       0.77      0.74      0.76       192
#
#     accuracy                           0.76       376
#    macro avg       0.76      0.76      0.76       376
# weighted avg       0.76      0.76      0.76       376

# %%
pickle.dump(model, open("model.pkl", "wb"))           
joblib.dump(ct, "feature_values.pkl")
# Out:
# ['feature_values.pkl']

# %%
abc = AdaBoostClassifier(random_state=99)
base = DecisionTreeClassifier(max_depth=3)
abc.fit(X_train,y_train)
pred_abc = abc.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.74       184
#            1       0.75      0.72      0.74       192
#
#     accuracy                           0.74       376
#    macro avg       0.74      0.74      0.74       376
# weighted avg       0.74      0.74      0.74       376
#
# [[138  46]
#  [ 53 139]]

# %%
log=LogisticRegression(solver='liblinear',random_state=49)
base = DecisionTreeClassifier(max_depth=3)
log.fit(X_train,y_train)
pred_abc = log.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73       184
#            1       0.75      0.73      0.74       192
#
#     accuracy                           0.74       376
#    macro avg       0.74      0.74      0.74       376
# weighted avg       0.74      0.74      0.74       376
#
# [[136  48]
#  [ 51 141]]

# %%
from sklearn.tree import DecisionTreeClassifier
dec=DecisionTreeClassifier(random_state=49)
base = DecisionTreeClassifier(max_depth=3)
dec.fit(X_train,y_train)
pred_abc = dec.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67       184
#            1       0.68      0.70      0.69       192
#
#     accuracy                           0.68       376
#    macro avg       0.68      0.68      0.68       376
# weighted avg       0.68      0.68      0.68       376
#
# [[121  63]
#  [ 58 134]]

# %%
from sklearn.ensemble import RandomForestClassifier
rad=RandomForestClassifier(random_state=49)
base = DecisionTreeClassifier(max_depth=3)
rad.fit(X_train,y_train)
pred_abc = rad.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       184
#            1       0.77      0.73      0.75       192
#
#     accuracy                           0.75       376
#    macro avg       0.75      0.75      0.75       376
# weighted avg       0.75      0.75      0.75       376
#
# [[141  43]
#  [ 51 141]]

# %%
gb=GradientBoostingClassifier(random_state=49)
base = DecisionTreeClassifier(max_depth=3)
gb.fit(X_train,y_train)
pred_abc = gb.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74       184
#            1       0.76      0.72      0.74       192
#
#     accuracy                           0.74       376
#    macro avg       0.74      0.74      0.74       376
# weighted avg       0.74      0.74      0.74       376
#
# [[140  44]
#  [ 53 139]]

# %%
kn=KNeighborsClassifier()
base = DecisionTreeClassifier(max_depth=3)
kn.fit(X_train,y_train)
pred_abc = kn.predict(X_test)
print(classification_report(y_test,pred_abc))
print(confusion_matrix(y_test,pred_abc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       184
#            1       0.69      0.65      0.67       192
#
#     accuracy                           0.67       376
#    macro avg       0.67      0.67      0.67       376
# weighted avg       0.67      0.67      0.67       376
#
# [[128  56]
#  [ 68 124]]

# %%
# 7. Train, predict, and evaluate each model
for name, model in model_dict.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("="*30 + f" {name} " + "="*30)
    print(f"Accuracy: {accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("\n")
# Out:
# ============================== Logistic regression ==============================
# Accuracy: 0.7367
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73       184
#            1       0.75      0.73      0.74       192
#
#     accuracy                           0.74       376
#    macro avg       0.74      0.74      0.74       376
# weighted avg       0.74      0.74      0.74       376
#
#
#
# ============================== KNN Classifier ==============================
# Accuracy: 0.6702
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       184
#            1       0.69      0.65      0.67       192
#
#     accuracy                           0.67       376
#    macro avg       0.67      0.67      0.67       376
# weighted avg       0.67      0.67      0.67       376
#
#
#
# ...

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# Define Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=49)

# Store results
cv_results = {}

print("Cross-Validation Scores (5-Fold):\n")

# Evaluate each model using cross_val_score
for name, model in model_dict.items():
    scores = cross_val_score(model, X_transformed, y, cv=skf, scoring='accuracy')
    cv_results[name] = scores
    print(f"{name}:")
    print(f"  Accuracy Scores: {scores}")
    print(f"  Mean Accuracy: {np.mean(scores):.4f}")
    print(f"  Std Deviation: {np.std(scores):.4f}")
    print("-" * 50)
# Out:
# Cross-Validation Scores (5-Fold):
#
# Logistic regression:
#   Accuracy Scores: [0.70916335 0.74501992 0.704      0.736      0.696     ]
#   Mean Accuracy: 0.7180
#   Std Deviation: 0.0190
# --------------------------------------------------
# KNN Classifier:
#   Accuracy Scores: [0.58964143 0.66135458 0.636      0.656      0.616     ]
#   Mean Accuracy: 0.6318
#   Std Deviation: 0.0265
# --------------------------------------------------
# Decision Tree Classifier:
#   Accuracy Scores: [0.70119522 0.65737052 0.672      0.632      0.68      ]
#   Mean Accuracy: 0.6685
#   Std Deviation: 0.0231
# --------------------------------------------------
# Random Forest Classifier:
#   Accuracy Scores: [0.74900398 0.76095618 0.728      0.72       0.728     ]
#   Mean Accuracy: 0.7372
#   Std Deviation: 0.0153
# --------------------------------------------------
# AdaBoost Classifier:
#   Accuracy Scores: [0.7689243  0.79282869 0.72       0.732      0.74      ]
#   Mean Accuracy: 0.7508
# ...

# %%
df_num_features = data.select_dtypes(include=['int64', 'float64'])

# Plot boxplots for each numerical feature
for k in df_num_features.columns:
    print(f"Boxplot for: {k}")
    sns.boxplot(data=data, x=k)
    plt.title(f"Boxplot of {k}")
    plt.show()
# Out:
# Boxplot for: Age
